# %%
import InfluxDbUtilities

# %% [markdown]
# ### You can Write data in the following way ###

# %% [markdown]
# Provide table_name (e.g : "City") ,tags (meta-data as dict),fields ({"NO2" :20,...} ),unixTime (Epoch time (Integer))

# %%
InfluxDbUtilities.write_data(table_name="home", tags= {"room": "Kitchen", "sensor": "K001"}, fields={"temp": 72.2, "hum": 36.9, "co": 4}, unixTime=1762372800)
